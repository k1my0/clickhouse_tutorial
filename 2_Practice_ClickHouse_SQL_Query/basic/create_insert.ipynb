# %%
import pandas as pd

from clickhouse_driver import Client
client = Client('localhost')

# %%
# https://clickhouse.tech/docs/en/getting-started/tutorial/
# https://github.com/ClickHouse/ClickHouse/tree/master/tests/queries/1_stateful
sql = """
-- tutorial.hits_v1

CREATE TABLE tutorial.hits_v1
(
    `WatchID` UInt64,
    `JavaEnable` UInt8,
    `Title` String,
    `GoodEvent` Int16,
    `EventTime` DateTime,
    `EventDate` Date,
    `CounterID` UInt32,
    `ClientIP` UInt32,
    `ClientIP6` FixedString(16),
    `RegionID` UInt32,
    `UserID` UInt64,
    `CounterClass` Int8,
    `OS` UInt8,
    `UserAgent` UInt8,
    `URL` String,
    `Referer` String,
    `URLDomain` String,
    `RefererDomain` String,
    `Refresh` UInt8,
    `IsRobot` UInt8,
    `RefererCategories` Array(UInt16),
    `URLCategories` Array(UInt16),
    `URLRegions` Array(UInt32),
    `RefererRegions` Array(UInt32),
    `ResolutionWidth` UInt16,
    `ResolutionHeight` UInt16,
    `ResolutionDepth` UInt8,
    `FlashMajor` UInt8,
    `FlashMinor` UInt8,
    `FlashMinor2` String,
    `NetMajor` UInt8,
    `NetMinor` UInt8,
    `UserAgentMajor` UInt16,
    `UserAgentMinor` FixedString(2),
    `CookieEnable` UInt8,
    `JavascriptEnable` UInt8,
    `IsMobile` UInt8,
    `MobilePhone` UInt8,
    `MobilePhoneModel` String,
    `Params` String,
    `IPNetworkID` UInt32,
    `TraficSourceID` Int8,
    `SearchEngineID` UInt16,
    `SearchPhrase` String,
    `AdvEngineID` UInt8,
    `IsArtifical` UInt8,
    `WindowClientWidth` UInt16,
    `WindowClientHeight` UInt16,
    `ClientTimeZone` Int16,
    `ClientEventTime` DateTime,
    `SilverlightVersion1` UInt8,
    `SilverlightVersion2` UInt8,
    `SilverlightVersion3` UInt32,
    `SilverlightVersion4` UInt16,
    `PageCharset` String,
    `CodeVersion` UInt32,
    `IsLink` UInt8,
    `IsDownload` UInt8,
    `IsNotBounce` UInt8,
    `FUniqID` UInt64,
    `HID` UInt32,
    `IsOldCounter` UInt8,
    `IsEvent` UInt8,
    `IsParameter` UInt8,
    `DontCountHits` UInt8,
    `WithHash` UInt8,
    `HitColor` FixedString(1),
    `UTCEventTime` DateTime,
    `Age` UInt8,
    `Sex` UInt8,
    `Income` UInt8,
    `Interests` UInt16,
    `Robotness` UInt8,
    `GeneralInterests` Array(UInt16),
    `RemoteIP` UInt32,
    `RemoteIP6` FixedString(16),
    `WindowName` Int32,
    `OpenerName` Int32,
    `HistoryLength` Int16,
    `BrowserLanguage` FixedString(2),
    `BrowserCountry` FixedString(2),
    `SocialNetwork` String,
    `SocialAction` String,
    `HTTPError` UInt16,
    `SendTiming` Int32,
    `DNSTiming` Int32,
    `ConnectTiming` Int32,
    `ResponseStartTiming` Int32,
    `ResponseEndTiming` Int32,
    `FetchTiming` Int32,
    `RedirectTiming` Int32,
    `DOMInteractiveTiming` Int32,
    `DOMContentLoadedTiming` Int32,
    `DOMCompleteTiming` Int32,
    `LoadEventStartTiming` Int32,
    `LoadEventEndTiming` Int32,
    `NSToDOMContentLoadedTiming` Int32,
    `FirstPaintTiming` Int32,
    `RedirectCount` Int8,
    `SocialSourceNetworkID` UInt8,
    `SocialSourcePage` String,
    `ParamPrice` Int64,
    `ParamOrderID` String,
    `ParamCurrency` FixedString(3),
    `ParamCurrencyID` UInt16,
    `GoalsReached` Array(UInt32),
    `OpenstatServiceName` String,
    `OpenstatCampaignID` String,
    `OpenstatAdID` String,
    `OpenstatSourceID` String,
    `UTMSource` String,
    `UTMMedium` String,
    `UTMCampaign` String,
    `UTMContent` String,
    `UTMTerm` String,
    `FromTag` String,
    `HasGCLID` UInt8,
    `RefererHash` UInt64,
    `URLHash` UInt64,
    `CLID` UInt32,
    `YCLID` UInt64,
    `ShareService` String,
    `ShareURL` String,
    `ShareTitle` String,
    `ParsedParams` Nested(
        Key1 String,
        Key2 String,
        Key3 String,
        Key4 String,
        Key5 String,
        ValueDouble Float64),
    `IslandID` FixedString(16),
    `RequestNum` UInt32,
    `RequestTry` UInt8
)
ENGINE = MergeTree()
PARTITION BY toYYYYMM(EventDate)
ORDER BY (CounterID, EventDate, intHash32(UserID))
SAMPLE BY intHash32(UserID)
SETTINGS index_granularity = 8192

;;

-- tutorial.visits_v1
CREATE TABLE tutorial.visits_v1
(
    `CounterID` UInt32,
    `StartDate` Date,
    `Sign` Int8,
    `IsNew` UInt8,
    `VisitID` UInt64,
    `UserID` UInt64,
    `StartTime` DateTime,
    `Duration` UInt32,
    `UTCStartTime` DateTime,
    `PageViews` Int32,
    `Hits` Int32,
    `IsBounce` UInt8,
    `Referer` String,
    `StartURL` String,
    `RefererDomain` String,
    `StartURLDomain` String,
    `EndURL` String,
    `LinkURL` String,
    `IsDownload` UInt8,
    `TraficSourceID` Int8,
    `SearchEngineID` UInt16,
    `SearchPhrase` String,
    `AdvEngineID` UInt8,
    `PlaceID` Int32,
    `RefererCategories` Array(UInt16),
    `URLCategories` Array(UInt16),
    `URLRegions` Array(UInt32),
    `RefererRegions` Array(UInt32),
    `IsYandex` UInt8,
    `GoalReachesDepth` Int32,
    `GoalReachesURL` Int32,
    `GoalReachesAny` Int32,
    `SocialSourceNetworkID` UInt8,
    `SocialSourcePage` String,
    `MobilePhoneModel` String,
    `ClientEventTime` DateTime,
    `RegionID` UInt32,
    `ClientIP` UInt32,
    `ClientIP6` FixedString(16),
    `RemoteIP` UInt32,
    `RemoteIP6` FixedString(16),
    `IPNetworkID` UInt32,
    `SilverlightVersion3` UInt32,
    `CodeVersion` UInt32,
    `ResolutionWidth` UInt16,
    `ResolutionHeight` UInt16,
    `UserAgentMajor` UInt16,
    `UserAgentMinor` UInt16,
    `WindowClientWidth` UInt16,
    `WindowClientHeight` UInt16,
    `SilverlightVersion2` UInt8,
    `SilverlightVersion4` UInt16,
    `FlashVersion3` UInt16,
    `FlashVersion4` UInt16,
    `ClientTimeZone` Int16,
    `OS` UInt8,
    `UserAgent` UInt8,
    `ResolutionDepth` UInt8,
    `FlashMajor` UInt8,
    `FlashMinor` UInt8,
    `NetMajor` UInt8,
    `NetMinor` UInt8,
    `MobilePhone` UInt8,
    `SilverlightVersion1` UInt8,
    `Age` UInt8,
    `Sex` UInt8,
    `Income` UInt8,
    `JavaEnable` UInt8,
    `CookieEnable` UInt8,
    `JavascriptEnable` UInt8,
    `IsMobile` UInt8,
    `BrowserLanguage` UInt16,
    `BrowserCountry` UInt16,
    `Interests` UInt16,
    `Robotness` UInt8,
    `GeneralInterests` Array(UInt16),
    `Params` Array(String),
    `Goals` Nested(
        ID UInt32,
        Serial UInt32,
        EventTime DateTime,
        Price Int64,
        OrderID String,
        CurrencyID UInt32),
    `WatchIDs` Array(UInt64),
    `ParamSumPrice` Int64,
    `ParamCurrency` FixedString(3),
    `ParamCurrencyID` UInt16,
    `ClickLogID` UInt64,
    `ClickEventID` Int32,
    `ClickGoodEvent` Int32,
    `ClickEventTime` DateTime,
    `ClickPriorityID` Int32,
    `ClickPhraseID` Int32,
    `ClickPageID` Int32,
    `ClickPlaceID` Int32,
    `ClickTypeID` Int32,
    `ClickResourceID` Int32,
    `ClickCost` UInt32,
    `ClickClientIP` UInt32,
    `ClickDomainID` UInt32,
    `ClickURL` String,
    `ClickAttempt` UInt8,
    `ClickOrderID` UInt32,
    `ClickBannerID` UInt32,
    `ClickMarketCategoryID` UInt32,
    `ClickMarketPP` UInt32,
    `ClickMarketCategoryName` String,
    `ClickMarketPPName` String,
    `ClickAWAPSCampaignName` String,
    `ClickPageName` String,
    `ClickTargetType` UInt16,
    `ClickTargetPhraseID` UInt64,
    `ClickContextType` UInt8,
    `ClickSelectType` Int8,
    `ClickOptions` String,
    `ClickGroupBannerID` Int32,
    `OpenstatServiceName` String,
    `OpenstatCampaignID` String,
    `OpenstatAdID` String,
    `OpenstatSourceID` String,
    `UTMSource` String,
    `UTMMedium` String,
    `UTMCampaign` String,
    `UTMContent` String,
    `UTMTerm` String,
    `FromTag` String,
    `HasGCLID` UInt8,
    `FirstVisit` DateTime,
    `PredLastVisit` Date,
    `LastVisit` Date,
    `TotalVisits` UInt32,
    `TraficSource` Nested(
        ID Int8,
        SearchEngineID UInt16,
        AdvEngineID UInt8,
        PlaceID UInt16,
        SocialSourceNetworkID UInt8,
        Domain String,
        SearchPhrase String,
        SocialSourcePage String),
    `Attendance` FixedString(16),
    `CLID` UInt32,
    `YCLID` UInt64,
    `NormalizedRefererHash` UInt64,
    `SearchPhraseHash` UInt64,
    `RefererDomainHash` UInt64,
    `NormalizedStartURLHash` UInt64,
    `StartURLDomainHash` UInt64,
    `NormalizedEndURLHash` UInt64,
    `TopLevelDomain` UInt64,
    `URLScheme` UInt64,
    `OpenstatServiceNameHash` UInt64,
    `OpenstatCampaignIDHash` UInt64,
    `OpenstatAdIDHash` UInt64,
    `OpenstatSourceIDHash` UInt64,
    `UTMSourceHash` UInt64,
    `UTMMediumHash` UInt64,
    `UTMCampaignHash` UInt64,
    `UTMContentHash` UInt64,
    `UTMTermHash` UInt64,
    `FromHash` UInt64,
    `WebVisorEnabled` UInt8,
    `WebVisorActivity` UInt32,
    `ParsedParams` Nested(
        Key1 String,
        Key2 String,
        Key3 String,
        Key4 String,
        Key5 String,
        ValueDouble Float64),
    `Market` Nested(
        Type UInt8,
        GoalID UInt32,
        OrderID String,
        OrderPrice Int64,
        PP UInt32,
        DirectPlaceID UInt32,
        DirectOrderID UInt32,
        DirectBannerID UInt32,
        GoodID String,
        GoodName String,
        GoodQuantity Int32,
        GoodPrice Int64),
    `IslandID` FixedString(16)
)
ENGINE = CollapsingMergeTree(Sign)
PARTITION BY toYYYYMM(StartDate)
ORDER BY (CounterID, StartDate, intHash32(UserID), VisitID)
SAMPLE BY intHash32(UserID)
SETTINGS index_granularity = 8192
"""

# %%
for s in sql.split(';;'):
#     print(s)
    client.execute(s.strip(''))
    print("done")
# Out:
# done
# done

# %%
! ls ../data
# Out:
# hits_v1.tsv   visits_v1.tsv

# %%
visits_v1 = pd.read_csv('../data/visits_v1.tsv', sep="\t", nrows=1000, encoding="latin1", header=None, error_bad_lines=False)
# Out:
# b'Skipping line 210: expected 181 fields, saw 280\nSkipping line 334: expected 181 fields, saw 478\nSkipping line 563: expected 181 fields, saw 280\nSkipping line 800: expected 181 fields, saw 282\nSkipping line 972: expected 181 fields, saw 280\nSkipping line 1174: expected 181 fields, saw 183\n'
# b'Skipping line 4552: expected 181 fields, saw 280\nSkipping line 4571: expected 181 fields, saw 280\nSkipping line 7816: expected 181 fields, saw 280\nSkipping line 7944: expected 181 fields, saw 280\n'
# b'Skipping line 8526: expected 181 fields, saw 280\nSkipping line 10107: expected 181 fields, saw 1171\nSkipping line 10399: expected 181 fields, saw 280\n'
# b'Skipping line 14179: expected 181 fields, saw 205\nSkipping line 14194: expected 181 fields, saw 203\nSkipping line 14501: expected 181 fields, saw 186\nSkipping line 14641: expected 181 fields, saw 307\nSkipping line 15594: expected 181 fields, saw 282\nSkipping line 15753: expected 181 fields, saw 206\nSkipping line 15916: expected 181 fields, saw 183\n'
# b'Skipping line 16421: expected 181 fields, saw 282\nSkipping line 18148: expected 181 fields, saw 208\nSkipping line 18951: expected 181 fields, saw 183\nSkipping line 19187: expected 181 fields, saw 280\nSkipping line 19347: expected 181 fields, saw 183\n'
# b'Skipping line 21130: expected 181 fields, saw 208\nSkipping line 21768: expected 181 fields, saw 183\nSkipping line 21818: expected 181 fields, saw 280\nSkipping line 22103: expected 181 fields, saw 206\nSkipping line 22118: expected 181 fields, saw 206\nSkipping line 22257: expected 181 fields, saw 282\nSkipping line 22616: expected 181 fields, saw 282\nSkipping line 22960: expected 181 fields, saw 244\nSkipping line 23006: expected 181 fields, saw 282\nSkipping line 23319: expected 181 fields, saw 282\n'
# b'Skipping line 25934: expected 181 fields, saw 280\nSkipping line 27475: expected 181 fields, saw 198\n'
# b'Skipping line 28992: expected 181 fields, saw 304\nSkipping line 29941: expected 181 fields, saw 577\nSkipping line 30305: expected 181 fields, saw 280\nSkipping line 30315: expected 181 fields, saw 379\nSkipping line 31262: expected 181 fields, saw 183\nSkipping line 31517: expected 181 fields, saw 183\nSkipping line 32028: expected 181 fields, saw 280\nSkipping line 32064: expected 181 fields, saw 282\nSkipping line 32531: expected 181 fields, saw 183\nSkipping line 32664: expected 181 fields, saw 282\nSkipping line 32708: expected 181 fields, saw 183\n'
# b'Skipping line 1469710: expected 181 fields, saw 282\nSkipping line 1469799: expected 181 fields, saw 307\nSkipping line 1472177: expected 181 fields, saw 183\n'
# b'Skipping line 1473062: expected 181 fields, saw 183\nSkipping line 1473424: expected 181 fields, saw 183\nSkipping line 1473519: expected 181 fields, saw 244\nSkipping line 1473528: expected 181 fields, saw 244\nSkipping line 1473628: expected 181 fields, saw 244\nSkipping line 1474835: expected 181 fields, saw 183\nSkipping line 1475023: expected 181 fields, saw 282\nSkipping line 1475541: expected 181 fields, saw 208\nSkipping line 1475733: expected 181 fields, saw 280\nSkipping line 1475853: expected 181 fields, saw 183\n'
# b'Skipping line 1476465: expected 181 fields, saw 183\nSkipping line 1476715: expected 181 fields, saw 186\nSkipping line 1476935: expected 181 fields, saw 208\nSkipping line 1477712: expected 181 fields, saw 304\nSkipping line 1479218: expected 181 fields, saw 183\nSkipping line 1479317: expected 181 fields, saw 208\nSkipping line 1479622: expected 181 fields, saw 304\nSkipping line 1480138: expected 181 fields, saw 280\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-503f67881c99> in <module>
# ----> 1 visits_v1 = pd.read_csv('../data/visits_v1.tsv', sep="\t", encoding="latin1", header=None, error_bad_lines=False)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     540
#     541
# --> 542 def is_categorical_dtype(arr_or_dtype) -> bool:
#     543     """
#     544     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
visits_v1
# Out:
#           0           1    2    3                    4                    5    \
# 0    10276349  2014-03-23    1    1  7806540595385905463  1344283236868090830
# 1    16619451  2014-03-23    1    1  8623558059760898915  4425926654910350113
# 2    16649448  2014-03-23    1    1  5472967741809414481   876526959237970489
# 3     8777593  2014-03-23    1    1  9197261161927707050  1019185474246230290
# 4    12933547  2014-03-23    1    1  6060941481232062770  1818709880897340153
# ..        ...         ...  ...  ...                  ...                  ...
# 995  20250679  2014-03-23    1    0  5320650369877840217  1357477044626071502
# 996  20250679  2014-03-23    1    0  8804789363896107993   543826922252315163
# 997  20250679  2014-03-23   -1    0  8993353493844726727  9422549030887237591
# 998  20250679  2014-03-23    1    0  8993353493844726727  9422549030887237591
# 999  20250679  2014-03-23   -1    0  5006803049426973110   140702092841926781
#
#                      6     7                    8    9    ...  171  172 173  \
# 0    2014-03-23 17:25:03     0  2014-03-24 03:30:58    1  ...   []   []  []
# 1    2014-03-23 17:24:40    11  2014-03-24 03:30:34    1  ...   []   []  []
# 2    2014-03-23 17:26:17    16  2014-03-24 03:32:14    3  ...   []   []  []
# 3    2014-03-23 17:27:30    31  2014-03-24 03:34:07    1  ...   []   []  []
# 4    2014-03-23 17:28:04     0  2014-03-24 03:35:02    1  ...   []   []  []
# ..                   ...   ...                  ...  ...  ...  ...  ...  ..
# 995  2014-03-23 12:03:34   336  2014-03-24 13:23:05   14  ...   []   []  []
# 996  2014-03-23 11:38:17    21  2014-03-24 12:50:34    1  ...   []   []  []
# 997  2014-03-23 11:09:04    47  2014-03-24 12:30:52    6  ...   []   []  []
# 998  2014-03-23 11:09:04  2039  2014-03-24 12:30:52    7  ...   []   []  []
# 999  2014-03-23 10:36:06  1996  2014-03-24 12:01:23    3  ...   []   []  []
#
#     174 175 176 177 178  179               180
# 0    []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 1    []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 2    []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 3    []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 4    []  []  []  []  []   []  %«ú=$Pjà2¶f_
# ..   ..  ..  ..  ..  ..  ...               ...
# 995  []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 996  []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 997  []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 998  []  []  []  []  []   []  %«ú=$Pjà2¶f_
# 999  []  []  []  []  []   []  %«ú=$Pjà2¶f_
#
# [1000 rows x 181 columns]

# %%
sql = """
INSERT INTO tutorial.visits_v1 FORMAT TSV
"""

client.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-72a81a19d441> in <module>
#       3 """
#       4
# ----> 5 client.execute(sql)
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/client.py in execute(self, query, params, with_column_types, external_tables, query_id, settings, types_check, columnar)
#     216                     external_tables=external_tables,
#     217                     query_id=query_id, types_check=types_check,
# --> 218                     columnar=columnar
#     219                 )
#     220             self.last_query.store_elapsed(time() - start_time)
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/client.py in process_ordinary_query(self, query, params, with_column_types, external_tables, query_id, types_check, columnar)
#     339                                              types_check=types_check)
#     340         return self.receive_result(with_column_types=with_column_types,
# --> 341                                    columnar=columnar)
#     342
#     343     def iter_process_ordinary_query(
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/client.py in receive_result(self, with_column_types, progress, columnar)
#      81                 gen, with_column_types=with_column_types, columnar=columnar
#      82             )
# ---> 83             return result.get_result()
#      84
#      85     def iter_receive_result(self, with_column_types=False):
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/result.py in get_result(self)
#      46         """
#      47
# ---> 48         for packet in self.packet_generator:
#      49             self.store(packet)
#      50
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/client.py in packet_generator(self)
#      93         while True:
#      94             try:
# ---> 95                 packet = self.receive_packet()
#      96                 if not packet:
#      97                     break
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/client.py in receive_packet(self)
#     107
#     108     def receive_packet(self):
# --> 109         packet = self.connection.receive_packet()
#     110
#     111         if packet.type == ServerPacketTypes.EXCEPTION:
#
# /usr/local/lib/python3.7/site-packages/clickhouse_driver/connection.py in receive_packet(self)
#     407         packet = Packet()
#     408
# --> 409         packet.type = packet_type = read_varint(self.fin)
#     410
#     411         if packet_type == ServerPacketTypes.DATA:
#
# clickhouse_driver/varint.pyx in clickhouse_driver.varint.read_varint()
#
# clickhouse_driver/bufferedreader.pyx in clickhouse_driver.bufferedreader.BufferedReader.read_one()
#
# clickhouse_driver/bufferedreader.pyx in clickhouse_driver.bufferedreader.BufferedSocketReader.read_into_buffer()
#
# KeyboardInterrupt:
